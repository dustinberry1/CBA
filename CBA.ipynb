# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.38.0-py2.py3-none-any.whl (8.7 MB)
#      ---------------------------------------- 8.7/8.7 MB 39.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\dusti\anaconda3\lib\site-packages (from streamlit) (4.12.2)
# Collecting pydeck<1,>=0.8.0b4
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#      ---------------------------------------- 6.9/6.9 MB 88.3 MB/s eta 0:00:00
# Requirement already satisfied: click<9,>=7.0 in c:\users\dusti\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\dusti\anaconda3\lib\site-packages (from streamlit) (1.4.4)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\dusti\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Collecting pyarrow>=7.0
#   Downloading pyarrow-17.0.0-cp39-cp39-win_amd64.whl (25.1 MB)
#      -------------------------------------- 25.1/25.1 MB 131.1 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\dusti\anaconda3\lib\site-packages (from streamlit) (3.20.3)
# Collecting altair<6,>=4.0
#   Downloading altair-5.4.1-py3-none-any.whl (658 kB)
#      ------------------------------------- 658.1/658.1 kB 40.5 MB/s eta 0:00:00
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\dusti\anaconda3\lib\site-packages (from streamlit) (13.8.0)
# Collecting tenacity<9,>=8.1.0
#   Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\dusti\anaconda3\lib\site-packages (from streamlit) (9.2.0)
# Collecting blinker<2,>=1.0.0
#   Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: packaging<25,>=20 in c:\users\dusti\anaconda3\lib\site-packages (from streamlit) (21.3)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\dusti\anaconda3\lib\site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\dusti\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\dusti\anaconda3\lib\site-packages (from streamlit) (1.23.5)
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ---------------------------------------- 207.3/207.3 kB ? eta 0:00:00
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\dusti\anaconda3\lib\site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\dusti\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\dusti\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.16.0)
# Requirement already satisfied: jinja2 in c:\users\dusti\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (2.11.3)
# Collecting narwhals>=1.5.2
#   Downloading narwhals-1.6.2-py3-none-any.whl (159 kB)
#      ---------------------------------------- 159.2/159.2 kB ? eta 0:00:00
# Requirement already satisfied: colorama in c:\users\dusti\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.7/62.7 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dusti\anaconda3\lib\site-packages (from packaging<25,>=20->streamlit) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dusti\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dusti\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dusti\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dusti\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dusti\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dusti\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.7.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dusti\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dusti\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\dusti\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.0.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\dusti\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\dusti\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (21.4.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dusti\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\dusti\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Installing collected packages: tenacity, smmap, pyarrow, narwhals, blinker, pydeck, gitdb, altair, gitpython, streamlit
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.0.1
#     Uninstalling tenacity-8.0.1:
#       Successfully uninstalled tenacity-8.0.1
# Successfully installed altair-5.4.1 blinker-1.8.2 gitdb-4.0.11 gitpython-3.1.43 narwhals-1.6.2 pyarrow-17.0.0 pydeck-0.9.1 smmap-5.0.1 streamlit-1.38.0 tenacity-8.5.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dusti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dusti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dusti\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\dusti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dusti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dusti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dusti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dusti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dusti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dusti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dusti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dusti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dusti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dusti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dusti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dusti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\dusti\anaconda3\lib\site-packages)

# %%
import streamlit as st

# %%
# Create input fields for the user to input values
st.title("4Runner vs Tesla Cost-Benefit Analysis")

# Inputs for 4Runner
st.header("4Runner")
gas_price_per_gallon = st.number_input("Gas price per gallon ($)", value=3.50)
mpg_4runner = st.number_input("4Runner MPG", value=18)
miles_per_year = st.number_input("Miles driven per year", value=12000)
maintenance_4runner = st.number_input("Annual maintenance cost for 4Runner ($)", value=1000)
insurance_4runner = st.number_input("Annual insurance cost for 4Runner ($)", value=1200)
depreciation_4runner = st.number_input("5-year depreciation for 4Runner ($)", value=3000)

# Inputs for Tesla
st.header("Tesla")
electricity_cost_per_kwh = st.number_input("Electricity cost per kWh ($)", value=0.15)
miles_per_kwh = st.number_input("Tesla efficiency (miles per kWh)", value=4)
maintenance_tesla = st.number_input("Annual maintenance cost for Tesla ($)", value=500)
insurance_tesla = st.number_input("Annual insurance cost for Tesla ($)", value=1500)
depreciation_tesla = st.number_input("5-year depreciation for Tesla ($)", value=1500)
purchase_cost_tesla = st.number_input("Purchase cost for Tesla ($)", value=45000)
trade_in_value_4runner = st.number_input("Trade-in value for 4Runner ($)", value=15000)
tax_incentives = st.number_input("Tax incentives for Tesla ($)", value=7500)

# Calculate 4Runner Costs
fuel_cost_4runner = (miles_per_year / mpg_4runner) * gas_price_per_gallon
total_4runner_costs = (fuel_cost_4runner + maintenance_4runner + insurance_4runner) * 5 + depreciation_4runner

# Calculate Tesla Costs
electricity_cost_tesla = (miles_per_year / miles_per_kwh) * electricity_cost_per_kwh
total_tesla_costs = (electricity_cost_tesla + maintenance_tesla + insurance_tesla) * 5 + depreciation_tesla + (purchase_cost_tesla - trade_in_value_4runner - tax_incentives)

# Display results
st.subheader("Results")
st.write(f"5-year total cost of owning the 4Runner: ${total_4runner_costs:,.2f}")
st.write(f"5-year total cost of owning the Tesla: ${total_tesla_costs:,.2f}")

# Compare Costs
cost_difference = total_4runner_costs - total_tesla_costs
if cost_difference > 0:
    st.success(f"Switching to the Tesla will save you ${cost_difference:,.2f} over 5 years.")
else:
    st.error(f"Switching to the Tesla will cost you an additional ${abs(cost_difference):,.2f} over 5 years.")
# Out:
# 2024-09-04 17:14:15.826 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.041
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\dusti\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-09-04 17:14:16.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.045 Session state does not function when running a script without `streamlit run`
# 2024-09-04 17:14:16.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.071 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-04 17:14:16.071 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
